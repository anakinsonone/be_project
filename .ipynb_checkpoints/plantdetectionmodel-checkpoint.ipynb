# %%
import tensorflow as tf
import pandas as pd 
from keras.utils import to_categorical
import random
import numpy as np
import os
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Activation, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img, array_to_img, img_to_array
from tensorflow.keras.models import Sequential
from glob import glob
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import tensorflow as tf
#       2 import pandas as pd
# ----> 3 from keras.utils import to_categorical
#       4 import random
#       5 import numpy as np
#
# ImportError: cannot import name 'to_categorical' from 'keras.utils' (C:\Users\akkhi\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\__init__.py)

# %%
#Importing the Dataset

# %%
IMAGE_SIZE = [224, 224]

train_path = r"C:\Users\Hp\Desktop\project\plant detection\tomato"
valid_path = r"C:\Users\Hp\Desktop\project\plant detection\tomato"

# %%
#Inception V3
# Import the InceptionV3 model and here we will be using imagenet weights

inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# ...
# 87916544/87910968 [==============================] - 19s 0us/step

# %%
# We don't need to train existing weights
for layer in inception.layers:
    layer.trainable = False

# %%
# Folders in the Training Set
folders = glob('C:/Users/Hp/Desktop/project/plant detection/tomato/train/*')
folders
# Out:
# ['C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Bacterial_spot',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Early_blight',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___healthy',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Late_blight',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Leaf_Mold',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Septoria_leaf_spot',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Spider_mites Two-spotted_spider_mite',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Target_Spot',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Tomato_mosaic_virus',
#  'C:/Users/Hp/Desktop/project/plant detection/tomato/train\\Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
# Model layers -> can add more if required
x = Flatten()(inception.output)
prediction = Dense(len(folders), activation='softmax')(x)

# %%
# Create a model object
model = Model(inputs=inception.input, outputs=prediction)

# View the structure of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 111, 111, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 109, 109, 32) 9216        activation[0][0]
# ...

# %%
# Defining the cost and model optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# Using the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Training Generator
training_set = train_datagen.flow_from_directory('C:/Users/Hp/Desktop/project/plant detection/tomato/train/',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 10000 images belonging to 10 classes.

# %%
# Testing Generator
test_set = test_datagen.flow_from_directory('C:/Users/Hp/Desktop/project/plant detection/tomato/train/',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 10000 images belonging to 10 classes.

# %%
# fit the model, it will take some time to execute
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=10,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 1017s 3s/step - loss: 4.6694 - accuracy: 0.5424 - val_loss: 1.7792 - val_accuracy: 0.7681
# Epoch 2/10
# 313/313 [==============================] - 1104s 4s/step - loss: 2.0807 - accuracy: 0.7520 - val_loss: 1.3459 - val_accuracy: 0.8314
# Epoch 3/10
# 313/313 [==============================] - 1058s 3s/step - loss: 1.9009 - accuracy: 0.7981 - val_loss: 1.5886 - val_accuracy: 0.8308
# Epoch 4/10
# 313/313 [==============================] - 1059s 3s/step - loss: 1.4913 - accuracy: 0.8446 - val_loss: 2.3742 - val_accuracy: 0.7823
# Epoch 5/10
# 313/313 [==============================] - 1117s 4s/step - loss: 1.7274 - accuracy: 0.8347 - val_loss: 1.8801 - val_accuracy: 0.8287
# Epoch 6/10
# 313/313 [==============================] - 1018s 3s/step - loss: 1.4440 - accuracy: 0.8603 - val_loss: 0.9611 - val_accuracy: 0.9005
# Epoch 7/10
# ...

# %%
#Visualize the model training by plotting Loss Function and Accuracy

# %%
# Plot the Loss and Accuracy
# Loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# Accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
# Saving the model as a h5 file

from tensorflow.keras.models import load_model
model.save('model_inception.h5')

# %%
y_pred = model.predict(test_set)
y_pred
# Out:
# array([[0.0000000e+00, 1.2650173e-35, 1.9945618e-18, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [3.0601816e-18, 1.0194164e-12, 9.9949932e-01, ..., 2.1049616e-20,
#         1.0913748e-25, 5.0065306e-04],
#        [0.0000000e+00, 0.0000000e+00, 1.7828908e-29, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        ...,
#        [8.8413511e-22, 2.3418377e-13, 1.9314678e-02, ..., 1.0412361e-01,
#         1.1260957e-35, 1.5535546e-27],
#        [0.0000000e+00, 1.0000000e+00, 8.2962959e-10, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [3.0733655e-28, 1.2897330e-25, 5.5980025e-12, ..., 1.3540011e-27,
#         0.0000000e+00, 1.0000000e+00]], dtype=float32)

# %%
import numpy as np
y_pred = np.argmax(y_pred, axis=1)
y_pred
# Out:
# array([3, 2, 6, ..., 5, 1, 9], dtype=int64)

# %%
import cv2
import tensorflow as tf
index = ['Bacterial_spot', 'Early_blight', 'healthy', 'Late_blight', 'Leaf_Mold','Septoria_leaf_spot','Spider_mites Two-spotted_spider_mite','Target_Spot','Tomato_mosaic_virus','Tomato_Yellow_Leaf_Curl_Virus']
